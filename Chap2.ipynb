# %%
import numpy as np

data = {i : np.random.randn() for i in range(7)}
# data.keys()
# data? ### using ? shows us the docstring
# data?? ### Using will also show the function’s source code if possible
# np.*? ### get a list of all functions in the top-level NumPy namespace
# np.*load*? ### get a list of all functions in the top-level NumPy namespace containing load

# %%
# %debug?
# %pwd
# %matplotlib inline

import matplotlib.pyplot as plt
plt.plot(np.random.rand(10))

# %%
from datetime import datetime, date, time

dt = datetime(2011, 10, 29, 20, 30, 21)

dt.second
dt.date()
dt.time()
dt.strftime('%m/%d/%Y %H:%M')
# Out:
# '10/29/2011 20:30'

# %%
sequence = [1,2,None,4,None,5]
total = 0
for value in sequence:
    if value is None:
        continue
    total += value
print(total)
# Out:
# 12
